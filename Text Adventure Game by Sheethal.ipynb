# %%
#Docstring: This is a story based journey game named "Always and Forever" developed by "Sheethal Melnarse" on October 2019.
#Bugs: *Under random name generator, i couldn't find a way to keep the same name when user enters something wrong and they get back to input box. Due to randomization, the name will change everytime when they get another change enter the right option.

#Sources: 1.Stackflow 2.github 3. The story is adapted from the TV series "The Originals".
#Contact: sheethalk98@gmail.com 
#         (+1) 857 285 8552 (Mobile)


#Importing required packages and defining variable

import time 
exit_var = True

exit_var1 = True
exit_var2 = True
exit_var3 = True
exit_var4 = True
exit_var5 = True
exit_var6 = True
exit_var7 = True
exit_var8 = True
global exit_var0
exit_var0 = True 
import random
import win32com.client as wincl
speak = wincl.Dispatch("SAPI.SpVoice")
from ipywidgets import *



#Defining a function to make it less complicated. This way, i can easily embed this inside a loop.
def niklaus_scenario_1():
    
    global exit_var
    global exit_var1
    
    time.sleep(2.0)
    print("""\033[1m"""+"""Objective:"""+"""\033[0m""" + """ You are embodying Niklaus's character so stay true to his personality traits and end game is to not be unloved and alone for eternity.""")
    time.sleep(2.5)
    print('\n\033[1m'+'Niklaus:'+'\033[0m' + ' My Siblings and I are the first vampires in all of history: The Original Family. Unlike them, I’m a hybrid: half vampire, half werewolf. Three hundred years ago, we helped build a city of New Orleans. Apparently, a witch named Jane Anne Deveraux is conspiring against me. I intend to find her and question her before I rip her head off.\n ')
    speak.Speak("My Siblings and I are the first vampires in all of history: The Original Family. Unlike them, I’m a hybrid: half vampire, half werewolf. Three hundred years ago, we helped build a city of New Orleans. Apparently, a witch named Jane Anne Deveraux is conspiring against me. I intend to find her and question her before I rip her head off.")
    time.sleep(1.5)
    print("""\nAfter arriving in New Orleans, you find out that your old friend Marcel, a vampire you sired controls the French quarter. Marcel is a tyrant; he has a rule that witches shouldn’t practice magic within the French quarter. He has learnt everything from you and owes his life to you. You approach him to seek his help in finding the witch conspiring against you.\n\n""") 
    time.sleep(4.0)
    print("""\033[1m"""+"""Marcel:"""+"""\033[0m""" +""" You ought to come with me. Haha Showtime!\n\n""" +
          """He takes you to the street in the middle of the night.\n\n""" +
          """\033[1m"""+"""Marcel:"""+"""\033[0m""" +""" Jane Anne Deveraux! You have been accused of the practice of witchcraft, beyond the bounds of the rules set forth and enforced by me. How do you plead? hahaa""")
    time.sleep(3.0)
    
    exit_var = True
    
    while(exit_var == True):
        
        Decision_N1 = input(prompt = '\nA. Kill her \nB. Let him interrogate her\n\n')
        Decision_N1 = Decision_N1.upper().strip()
       
        if 'KILL' in Decision_N1 or Decision_N1 == 'A' or Decision_N1 == 'A.' or Decision_N1 == 'KILL HER':
            time.sleep(1.5)
            print("""\n\033[1m"""+"""SNAP!"""+"""\033[0m""")
            time.sleep(1.0)
            print('\nYou snapped her neck and she is dead. Now you have no idea what was her agenda was and whether she was working alone.\n')
            time.sleep(2.0)
            exit_var = False
        
        elif 'INTERROGATE' in Decision_N1 or Decision_N1 == 'B' or Decision_N1 == 'B.' or Decision_N1 == 'LET HIM INTERROGATE HER':
            print("""\n\033[1m"""+"""Marcel:"""+"""\033[0m""" + """ Seriously Jane, how do you plead?\n\n""" +
                  """\033[1m"""+"""Jane:"""+"""\033[0m""" + """ I didn’t do anything!\n\n""" + 
                  """\033[1m"""+"""Marcel:"""+"""\033[0m""" + """ That’s a lie. You know it, I know it and you hate that I know it.\n\n""" +
                  """\033[1m"""+"""Jane:"""+"""\033[0m""" + """ Rot in hell monster!""")
            time.sleep(4.5)
            print("\nMarcel rips her throat off")
            time.sleep(2.0)
            print("\nYou have a dead witch, now you have no idea whether what was her agenda and whether she was working alone.")
            exit_var = False
    
        else:
            print('\nDamn! You made a mistake, try again!.')
            
    time.sleep(1.5)
    print("\n\nLater that night, when you are drinking alone in the balcony, your older brother Elijah surprises you with a visit.")  
    time.sleep(2.0)
    
    print("""\n\033[1m"""+"""You:"""+"""\033[0m""" + """ Evening Elijah!\n\n""" + 
          """\033[1m"""+"""Elijah:"""+"""\033[0m""" + """ Niklaus!\n\n""" + 
          """\033[1m"""+"""You:"""+"""\033[0m""" + """ What an entirely unwelcomed surprise.\n\n""" + 
          """\033[1m"""+"""Elijah:"""+"""\033[0m""" + """ And what an entirely unsurprising welcome. You wanna know what witches have in store for you ? Follow me.\n""")
    
    time.sleep(2.5)
    
    print("""\nElijah takes you to the cemetery to meet Sophie Deveraux, Jane’s younger sister. Sophie tells that they have Hayley, a werewolf with whom you spent a ‘fun’ night couple of months ago and now she is pregnant with your child.""")

    time.sleep(1.5)
    print("""\n\033[1m"""+"""You:"""+"""\033[0m""" + """ No. It’s impossible.\n""" + 
          """\n\033[1m"""+"""You:"""+"""\033[0m""" + """ This is a lie. You’re all lying. Vampires can’t procreate.\n""" + 
          """\n\033[1m"""+"""Sophie:"""+"""\033[0m""" + """ But werewolves can. Magic made you a vampire, but you were born a werewolf. You’re the original hybrid, and this pregnancy is one of nature’s loopholes.\n""" + 
          """\n\033[1m"""+"""Sophie:"""+"""\033[0m""" + """ We can keep them safe or kill them if you don’t help us take down Marcel.\n""" + 
          """\n\033[1m"""+"""Elijah:"""+"""\033[0m""" + """ If you want Marcel dead, he’s dead. I’ll do it myself.\n""" + 
          """\n\033[1m"""+"""Sophie:"""+"""\033[0m""" + """ No. we can’t, not yet. We have a clear plan that we need to follow, and there are rules.\n""")
    time.sleep(3.5)
    
    exit_var1 = True
    
    while(exit_var1 == True):
        
        Decision_N2 = input(prompt = 'A. Agree to her terms \nB. Attack and kill every witch \nC. Take a minute to process\n')
        Decision_N2 = Decision_N2.upper().strip()
        
        if 'AGREE' in Decision_N2 or Decision_N2 == 'A' or Decision_N2 == 'A.' or Decision_N2 == 'AGREE TO HER TERMS' or Decision_N2 == 'TERMS':
            time.sleep(1.5)
            print("""\n\033[1m"""+"""You:"""+"""\033[0m""" +""" Fine! We have a deal.""")
            time.sleep(2.0)
            niklaus_scenario_3()
            time.sleep(1.5)
            rand_name_generator()
            time.sleep(1.5)
            print("\nShe becomes your North Star and you begin your journey towards redemption. You finally find peace and live happily hereafter.")
            time.sleep(2.0)
            print("\nNow you have become a better person than you were, after playing this game. Would you like to play again?")
            exit_var1 = False
            
        elif 'ATTACK' in Decision_N2 or Decision_N2 == 'B' or Decision_N2 == 'B.' or Decision_N2 == 'ATTACK AND KILL EVERY WITCH' or Decision_N2 == 'KILL':
            time.sleep(1.5)
            print("""\n\033[1m"""+"""You:"""+"""\033[0m"""+""" How dare you command me, threaten me with what you wrongfully perceive to be my weaknesses? This is a pathetic deception.""")
            time.sleep(2.0)
            print("""\nYou try to attack only to be interfered by Elijah, who says Hayley and Sophie are magically linked. So, if anything physically happens to Sophie, Hayley and the baby dies. You pause and think for a second then decide to leave… Elijah follows you…""")
            niklaus_scenario_2()
            
            exit_var1 = False
        
        elif 'MINUTE' in Decision_N2 or Decision_N2 == 'C' or Decision_N2 == 'C.' or Decision_N2 == 'TAKE A MINUTE TO PROCESS' or Decision_N2 == 'TAKE' or Decision_N2 == 'PROCESS':
            time.sleep(1.5)
            print("""\n\033[1m"""+"""You:"""+"""\033[0m"""+""" How dare you command me, threaten me with what you wrongfully perceive to be my weaknesses? This is a pathetic deception.""")
            time.sleep(2.0)
            print("""\n\033[1m"""+"""You:"""+"""\033[0m"""+""" Kill her and the baby, what do I care? (You leave the cemetery…)""")
            print("Elijah follows you...")
            niklaus_scenario_2()
            
            exit_var1 = False
        else:
            print('\nDamn! You made a mistake, try again!.')

def niklaus_scenario_2():
    
    global exit_var2
    global exit_var3
    global exit_var4
            
    time.sleep(2.0)
    print("""\n\n\033[1m"""+"""Elijah:"""+"""\033[0m"""+ """ It’s a gift brother. For 1,000 years, all we ever wanted was a family and it’s our shot at happiness."""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ I will not be manipulated."""+
          """\n\n\033[1m"""+"""Elijah:"""+"""\033[0m"""+ """ So, they’re manipulating you. So what? With them… this girl and your child… live. Is it so important to you that people quake with fear at the sound of your name?"""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ People quake with fear because I have the power to make them afraid. What will this child offer me? Will it guarantee me power?"""+
          """\n\n\033[1m"""+"""Elijah:"""+"""\033[0m"""+ """ Family is power, Niklaus. Love, loyalty, it’s power. This is what we swore to one another 1,000 years ago. This is us; the original family and we remain together always and forever."""+
          """\n\n\033[1m"""+"""Elijah:"""+"""\033[0m"""+ """ So, save this girl and your child.""")
    
    exit_var2 = True
    while(exit_var2 == True):
        
        Decision_N3 = input(prompt = 'A. Okay \nB. NO\n')
        Decision_N3 = Decision_N3.upper().strip()
        
        if 'Y' in Decision_N3 or 'OK' in Decision_N3 or Decision_N3 == 'A' or Decision_N3 == 'A.' or Decision_N3 == 'OKAY':
            time.sleep(1.5)
            print("""\n\033[1m"""+"""You:"""+"""\033[0m"""+""" Tell Sophie Deveraux we have a deal!""")
            time.sleep(2.0)
            niklaus_scenario_3()
            time.sleep(1.5)
            rand_name_generator()
            time.sleep(1.5)
            print("\nShe becomes your North star and you begin your journey towards redemption. You finally find peace and live happily hereafter.")
            time.sleep(2.0)
            print("\nNow you have become a better person than you were, after playing this game. Would you like to play again?")

            exit_var2 = False
        
        elif 'N' in Decision_N3 or Decision_N3 == 'B' or Decision_N3 == 'B.' or Decision_N3 == 'NO':
            time.sleep(1.5)
              
            print("\nElijah still follows you...\n")
            time.sleep(1.0)
            
            exit_var3 = True
            while(exit_var3 == True):
                
                Decision_N4 = input(prompt = '\nA. Fight him \nB. Let him follow\n')
                Decision_N4 = Decision_N4.upper().strip()
        
                if 'FIGHT' in Decision_N4 or Decision_N4 == 'A' or Decision_N4 == 'A.' or Decision_N4 == 'FIGHT HIM':
                    time.sleep(1.5)
                    print("""\n\033[1m"""+"""Bamm!!!"""+"""\033[0m""")
                    time.sleep(1.5)
                    print("""You sucker punch him; He fights back""")
                    exit_var3 = False
        
                elif 'FOLLOW' in Decision_N4 or Decision_N4 == 'B' or Decision_N4 == 'B.' or Decision_N4 == 'LET HIM FOLLOW' or Decision_N4 == 'LET':
                    time.sleep(1.5)
                    print("""\n\033[1m"""+"""Bamm!!!"""+"""\033[0m""")
                    time.sleep(1.5)
                    print("""He sucker punches you; You fight back""")
                    exit_var3 = False
        
                else:
                    print('\nDamn! You made a mistake, try again!.')
    
            time.sleep(2.0)
            print("""You both manage to land some heavy punches and break a few ribs (Don’t worry! You both are immortal; it will heal within seconds). In the end, you put him down since you are stronger than him (Hybrid).""")
            time.sleep(2.0)
            print("You feel bad and come to your senses. You offer him a hand and you both take a walk under the moon.")
            time.sleep(2.0)
            print("""\n\n\033[1m"""+"""You:"""+"""\033[0m"""+""" This town was my home once, and in my absence, Marcel has got everything I ever wanted. Power, loyalty, family. I made him in my image, and he has bettered me."""+
                  """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+""" I want what he has. I want it back. I want to be King."""
                  """\n\n\033[1m"""+"""Elijah:"""+"""\033[0m"""+ """ What about the girl and the child?""")
            time.sleep(3.5)
            
            exit_var4 = True
            while(exit_var4 == True):
                
                Decision_N5 = input(prompt = """A. “Every King needs an heir.” \nB. “I still don’t care.”\n""")
                Decision_N5 = Decision_N5.upper().strip()
        
                if 'KING' in Decision_N5 or Decision_N5 == 'A' or Decision_N5 == 'A.' or 'EVERY' in Decision_N5 or 'HEIR' in Decision_N5:
                    time.sleep(1.5)
                    print("""\n\033[1m"""+"""You:"""+"""\033[0m"""+""" Tell Sophie Deveraux we have a deal!""")
                    time.sleep(2.0)
                    niklaus_scenario_3()
                    time.sleep(1.5)
                    rand_name_generator()
                    time.sleep(1.5)
                    print("\nShe becomes your North Star and you begin your journey towards redemption. You finally find peace and live happily hereafter.")
                    time.sleep(2.0)
                    print("\nNow you have become a better person than you were, after playing this game. Would you like to play again?")

                    exit_var4 = False
        
                elif "DON'T" in Decision_N5 or Decision_N5 == 'B' or Decision_N5 == 'B.' or Decision_N5 == "I STILL DON'T CARE":
                    time.sleep(1.5)
                    print("Failed! You live alone for eternity without being loved or cared by anyone.")
                    time.sleep(1.5)
                    Decision_N6 = input(prompt = """< Press enter to go back and change your decision >\n""")
            
                else:
                    print('\nDamn! You made a mistake, try again!.')
                    
            exit_var2 = False
        
        else:
            print('\nDamn! You made a mistake, try again!.')

            
def niklaus_scenario_3():
    
    print("""\n\033[1m"""+"""-------- 7 MONTHS LATER --------"""+"""\033[0m""")
    time.sleep(1.5)
    print("""\n\033[1m"""+"""Congratulations!!"""+"""\033[0m"""+""" You are now a father to a beautiful baby girl.""")
    time.sleep(2.0)

    
def rand_name_generator():
    
    print("\nYou are recalling about your family tree to pick one of your Viking ancestor's name")
    Name_gen = input(prompt = "\n< Press enter to pick a historical name >\n")
    Names = ["Hope","Freya","Katherine","Caroline","Camille","Aurora","Katerina","Davina","Genevieve","Amara","Valerie","Astrid","Rebekah","Olivia","Alexandria"]
    N_tries = 2
    
    while len(Names) > 0:
        
        i = random.randint(0,len(Names)-1)
        print(f"\nWhat do you think of '{Names[i]}'?")
        print(f"(You have {N_tries} tries remaining)")
        User = input(prompt = "\nA. Love it \nB. Not so great\n\n")
        User = User.upper().strip()
        if User == "B" or User == "B." or "N" in User:
          
            if N_tries > 0:
                
                Names.remove(Names[i])      
                N_tries -= 1
            else:
                print(f"You: I think I'll stick with '{Names[i]}'")
                break
          
        elif User == "A" or User == "A." or "Love" in User:
            break
            
        else:
            print('\nDamn! You made a mistake, try again!')
    
    
    print(f"\n{Names[i]} \n\n{Names[i]} Mikaelson! That’s a worthy name to carry your family’s legacy.")
        
     
            
def elijah_scenario_1():
    
    global exit_var5
    global exit_var6
    global exit_var7
    global exit_var8
    
    print("""\033[1m"""+"""Objective:"""+"""\033[0m""" + """ You are embodying Elijah's character so stay true to his personality traits, end game is to help Niklaus get redemption and mend his broken family.""")
    time.sleep(2.5)
    print('\n\033[1m'+'Elijah:'+'\033[0m' + ' My Siblings and I are the first vampires in all of history: The Original Family. Three hundred years ago, we helped build a city of New Orleans. Over the course of my long life, I have come to believe that we are bound forever to those with whom we share blood and while we may not choose our family, their bond can be our greatest strength, or our deepest regret. \nThis unfortunate truth has haunted me for as long as I can recall. \nApparently, a witch named Jane Anne Deveraux is conspiring against my brother (Niklaus). I intend to find her and question her before my brother does something impulsive.')

    speak.Speak("My Siblings and I are the first vampires in all of history: The Original Family. Three hundred years ago, we helped build a city of New Orleans. Over the course of my long life, I have come to believe that we are bound forever to those with whom we share blood and while we may not choose our family, their bond can be our greatest strength, or our deepest regret. \nThis unfortunate truth has haunted me for as long as I can recall. \nApparently, a witch named Jane Anne Deveraux is conspiring against my brother Niklaus. I intend to find her and question her before my brother does something impulsive.")
        
    print("\nAfter arriving in New Orleans, you find out that your old friend Marcel, a vampire your brother (Niklaus) sired controls the French quarter. Marcel is a tyrant; he has a rule that witches shouldn’t practice magic within the French quarter. He has learnt everything he knows from your brother.")  
    time.sleep(2.0)
    print("\nYou also find out that Marcel killed Jane Anne Deveraux in the street in front of your brother moments before you arrived. You decide to take a stroll and speak with local witches about Jane. Thanks to your reputation of being ‘honorable’, they tell you that Jane has a sister named Sophie Deveraux, who works as a chef in a bar on Bourbon street.")
    time.sleep(2.0)
    print("\nWhen you are walking towards a bar, you notice a girl wearing white apron being harassed by a couple of vampires.\n")
    
    exit_var5 = True
    while(exit_var5 == True):
                
        Decision_E1 = input(prompt = "\nWhat do you wanna do? \n\nA. Attack and kill them \nB. There’s 2 of them. I’m afraid I’ll lose \nC. Maybe that’s not Sophie. I’ll go inside the bar and ask for Sophie\n")
        Decision_E1 = Decision_E1.upper().strip()
        
        if 'ATTACK' in Decision_E1 or 'KILL'in Decision_E1 or Decision_E1 == 'A' or Decision_E1 == 'A.':
            time.sleep(1.5)
            print("""\n\033[1m"""+"""Swoosh!!"""+"""\033[0m""")
            time.sleep(1.5)
            print("""\nYou use your super speed and rip out the beating heart from both of their chest simultaneously.""")
            exit_var5 = False
        
        elif '2' in Decision_E1 or 'TWO' in Decision_E1 or Decision_E1 == 'B' or Decision_E1 == 'B.' or 'AFRAID' in Decision_E1 or 'LOSE' in Decision_E1:
            time.sleep(2.0)
            print("""\nNo. You can take them both down, you are the original vampire. They are like flies compared to you.""")
        
        elif 'MAYBE' in Decision_E1 or 'C' in Decision_E1 or 'C.' in Decision_E1 or 'NOT' in Decision_E1 or 'SOPHIE' in Decision_E1 or 'INSIDE' in Decision_E1 or 'BAR' in Decision_E1:
            time.sleep(1.5)
            print("""Wrong! That was Sophie and she is dead now. There no more Deveraux witches, now you have no idea what her sister’s agenda was and whether she was working alone.""")
        
        else:
            print('\nDamn! You made a mistake, try again!.')
    
    time.sleep(2.0)
    
    print("""\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ I’m Elijah….. You heard of me?"""+
          """\n\n\033[1m"""+"""Sophie:"""+"""\033[0m"""+""" (with fear) ye... ye.. Yes! You and your family are famous amongst the witches."""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ So, why don’t you tell me what business your family has with my brother?"""+
          """\n\nShe takes you to the cemetery…"""+
          """\n\n\033[1m"""+"""Sophie:"""+"""\033[0m"""+""" We can talk freely here.""")
    time.sleep(2.5)
    print("""\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ What did your sister want with Niklaus?"""+
          """\n\n\033[1m"""+"""Sophie:"""+"""\033[0m"""+ """ Isn’t it obvious? We have a vampire problem, and we need help. Marcel has an army backing him. Witches have been trying to fight back but we haven’t had much luck until my sister met a werewolf girl named Hayley passing through the French quarter. Apparently, she and your brother both spent a ‘fun’ night together couple of months ago and now she is pregnant with his child."""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ It’s impossible. Vampires can’t procreate.""")
    time.sleep(2.5)
    print("""\n\n\033[1m"""+"""Sophie:"""+"""\033[0m""" + """ Think about it, he is a hybrid, right? Magic made him a vampire, but he was born a werewolf, and this pregnancy is one of nature’s loopholes."""+ """\n\033[1m"""+"""Sophie:"""+"""\033[0m"""+ """Convince your brother to help us, and the girl doesn’t get hurt."""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ Sounds remarkably like blackmail."""+
          """\n\n\033[1m"""+"""Sophie:"""+"""\033[0m"""+ """ Well, I’m desperate."""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ I have my work cut out for me, don’t I?""")
    time.sleep(3.0)
    
    exit_var6 = True            
    while(exit_var6 == True):
        
        Decision_E2 = input(prompt = '\nA. Call him \nB. Meet him in person\n')
        Decision_E2 = Decision_E2.upper().strip()
        
        if 'CALL' in Decision_E2 or Decision_E2 == 'A' or Decision_E2 == 'A.':
            time.sleep(1.5)
            print("""\nYou call him several times, but he keeps dismissing your call.""")
            time.sleep(1.5)
            exit_var6 = False
        
        elif 'MEET' in Decision_E2 or Decision_E2 == 'B' or Decision_E2 == 'B.' or 'PERSON' in Decision_E2:
            time.sleep(1.5)
            exit_var6 = False
        
        else:
            print('\nDamn! You made a mistake, try again!.')
    
    print("\nYou find him drinking alone in the balcony of your old house.")
    time.sleep(1.5)
    print("""\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ Evening Elijah!"""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ Niklaus!"""+
          """\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ What an entirely unwelcomed surprise."""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ And what an entirely unsurprising welcome. You wanna know what witches have in store for you? Follow me.""" )
    time.sleep(3.0)
    print("He comes with you to the cemetery, where you explain all about Hayley being pregnant with his child and their offer.")
    time.sleep(1.5)
    print("""\n\n\033[1m"""+"""Sophie:"""+"""\033[0m"""+ """ We want your help in taking down Marcel and you need to follow our rules if you want your baby to be born."""+
          """\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ How dare you command me, threaten me with what you wrongfully perceive to be my weaknesses? This is a pathetic deception."""+
          """\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ Kill her and the baby, what do I care?"""+
          """\n\nHe leaves.....""")
    time.sleep(3.5)
    
    exit_var7 = True
    while(exit_var7 == True):
        
        Decision_E3 = input(prompt = '\nA. Follow him to persuade to change his decision \nB. Stay and offer to help take down Marcel by yourself\n')
        Decision_E3 = Decision_E3.upper().strip()
        
        if 'FOLLOW' in Decision_E3 or 'PERSUADE' in Decision_E3 or 'CHANGE' in Decision_E3 or 'DECISION' in Decision_E3 or Decision_E3 == 'A' or Decision_E3 == 'A.':
            time.sleep(1.5)
            exit_var7 = False
        
        elif 'STAY' in Decision_E3 or Decision_E3 == 'B' or Decision_E3 == 'B.' or 'OFFER' in Decision_E3 or 'HELP' in Decision_E3 or 'TAKE' in Decision_E3:
            time.sleep(1.5)
            print("\nSophie doesn’t accept your offer. She says, they need Niklaus as well. She gives you an hour to change his mind. \n\nSo, you go after him...")
            time.sleep(2.0)
            exit_var7 = False
        
        else:
            print('\nDamn! You made a mistake, try again!.')
            
    print("""\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ It’s a gift brother. For 1,000 years, all we ever wanted was a family and it’s our shot at happiness."""+
          """\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ I will not be manipulated."""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ So, they’re manipulating you. So what? With them… this girl and your child… live. Is it so important to you that people quake with fear at the sound of your name?"""+
          """\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ People quake with fear because I have the power to make them afraid. What will this child offer me? Will it guarantee me power?"""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ Family is power, Niklaus. Love, loyalty, it’s power. This is what we swore to one another 1,000 years ago. This is us; the original family and we remain together always and forever.""")
    
    time.sleep(4.5)
          
    print("""\n\n\033[1m"""+"""You:"""+"""\033[0m"""+""" So, save this girl and your child."""+ 
          """\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ NO!""")
    time.sleep(1.5)
        
    exit_var8 = True    
    while(exit_var8 == True):
          
          Decision_E4 = input(prompt = '\nA. Fight him! \nB. Leave him alone\n')
          Decision_E4 = Decision_E4.upper().strip()
        
          if 'FIGHT' in Decision_E4 or Decision_E4 == 'A' or Decision_E4 == 'A.':
              time.sleep(1.5)
              print("""\n\033[1m"""+"""Bamm!!!"""+"""\033[0m""")
              time.sleep(1.5)
              print("""You sucker punch him; he fights back. You both manage to land some heavy punches and break a few ribs (Don’t worry! You both are immortal; it will heal within seconds). In the end, he puts you down since he is stronger than you (Hybrid).""")
              time.sleep(2.5)
              print("He feels bad and comes to his senses. He offers you a hand and you both take a walk under the moon.")
              time.sleep(2.0)
              exit_var8 = False
        
          elif 'LEAVE' in Decision_E4 or Decision_E4 == 'B' or Decision_E4 == 'B.' or 'ALONE' in Decision_E4:
                  
                time.sleep(1.5)
                print("\nFailed! Hayley and the child dies, your family remains broken and miserable for eternity.")
                time.sleep(2.0)
        
          else:          
                print('\nDamn! You made a mistake, try again!.')

    print("""\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ This town was my home once, and in my absence, Marcel has got everything I ever wanted. Power, loyalty, family. I made him in my image, and he has bettered me."""+
          """\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ I want what he has. I want it back. I want to be King."""+
          """\n\n\033[1m"""+"""You:"""+"""\033[0m"""+ """ What about the girl and the child?"""+
          """\n\n\033[1m"""+"""Niklaus:"""+"""\033[0m"""+ """ (With smile) Every King needs an heir! Tell Sophie Deveraux we have a deal.""")
          
    
def always_and_forever():
          
        global exit_var
        #Converting text to art
        from pyfiglet import Figlet    
        custom_fig = Figlet(font='Shadow')
        print(custom_fig.renderText('Always    and    Forever'))

        #Introduction and setting the scene to start the game.
        Welcome = "Welcome to New Orleans and the crown jewel of the cresent city: The French quarter...\nJazz and jambalaya, romance and poetry, not to mention things that go bump in the night, monsters that feed off human blood, vengeful spirits of the dead, and the witches.\nIt's a supernatural playground where living are easily lost, dead stick around to play."
        print(Welcome)

        #time function used to control the flow
        time.sleep(1.5)

        #Converting text to speech
        speak.Speak("Welcome to New Orleans and the crown jewel of the cresent city: The French quarter...\nJazz and jambalaya, romance and poetry, not to mention things that go bump in the night, monsters that feed off human blood, vengeful spirits of the dead, and the witches.\nIt's a supernatural playground where living are easily lost, dead stick around to play.")

        print('-'*124)  #Separation 

        #Defining a variable for space in a sentence. I'm using it for alignment.
        x = ' '

        #Character's biography
        print('\033[1m'+'Niklaus Mikaelson'+'\033[0m')
        print("Born" + 14*x + ": 990 A.D." + "\nGender" + 12*x + ": Male" + "\nSpecies" + 11*x + ": Original Hybrid (Werewolf/Vampire)" + "\nHeight" + 12*x + ": 5'11\"" + "\nHair Color" + 8*x + ": Dark Blonde" + "\nEye Color" + 9*x + ": Dark blue-green" + "\nAttire" + 12*x +": Casuals (usually with leather jacket on top)" + "\nPersonality traits" + ": Paranoid, Narcissistic, Defiant, Tempermental, Unforgiving")

        print('-'*124)

        print('\033[1m'+'Elijah Mikaelson'+'\033[0m')
        print("Born" + 14*x + ": 978 A.D." + "\nGender" + 12*x + ": Male" + "\nSpecies" + 11*x + ": Original Vampire" + "\nHeight" + 12*x + ": 5'10\"" + "\nHair Color" + 8*x + ": Brown" + "\nEye Color" + 9*x + ": Brown" + "\nAttire" + 12*x + ": Always wears a suit" + "\nPersonality traits" + ": Selfless, Honorable, Noble, Sentimental, Over-protective")
        print('-'*124)
        time.sleep(4.0)
        
        exit_var = True
        while(exit_var == True):
          
            Character_choose = input(prompt = 'Which character would you like to embody? \nA. Niklaus Mikaelson \nB. Elijah Mikaelson\n\n')
            Character_choose = Character_choose.upper().strip()

            if Character_choose == 'A' or Character_choose == 'NIKLAUS MIKAELSON' or Character_choose == 'NIKLAUS' or Character_choose == 'A.':
                niklaus_scenario_1() #Have used def() so that i can connect this and one of the elif in this loop
        
                exit_var = False
    
            #EASTER EGG! People familier with this TV series know that everybody other than his family calls him 'Klaus'
    
            elif Character_choose == 'KLAUS' or Character_choose == 'NIK' or Character_choose == 'NICK':
                custom_fig = Figlet(font='Shadow')
                print(custom_fig.renderText('SPECTACULAR'))
                speak.Speak('Spectacular!')
                niklaus_scenario_1()    #Have used def() so that i can connect this and if in this loop
                exit_var = False

            elif Character_choose == 'B' or Character_choose == 'ELIJAH MIKAELSON' or Character_choose == 'ELIJAH' or Character_choose == 'B.':
                elijah_scenario_1()
                print("""\n\033[1m"""+"""-------- 7 MONTHS LATER --------"""+"""\033[0m""")
                time.sleep(1.5)
                print("""\n\033[1m"""+"""Congratulations!!"""+"""\033[0m"""+""" You are now an Uncle to a beautiful baby girl.""")
                time.sleep(2.0)
                print("\nNiklaus is asking you to name her, for being relentless to save the family.")
                rand_name_generator()
                time.sleep(1.5)
                print("\nShe becomes his North Star and he begins his journey towards redemption. He finally finds peace and lives happily hereafter.")
                time.sleep(2.0)
                print("\nNow you have become more selfless person than you were, after playing this game. Would you like to play again?")
                exit_var = False
            else:
                print('\nDamn! You made a mistake, try again!')


while (exit_var0 == True):
    always_and_forever()    
    time.sleep(1.5)
    Replay = input(prompt = "\nYes \nNo\n")
    Replay = Replay.upper().strip()
          
    if 'Y' in Replay or 'YES' in Replay:
        print("Awesome!")
        time.sleep(1.5)
              
          
    elif 'N' in Replay or 'No' in Replay:
        print("Thanks for playing.")
        exit_var0 = False
          
    else:
        print('\nDamn! You made a mistake, try again!')

print("\nPlease rate your experience. \n 1 being the worst and 5 being the best")
Feed = widgets.IntSlider(
    value=3,
    min=1,
    max=5,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
display(Feed)
time.sleep(1.5)
Feedback = input(prompt = "\n< Press enter to submit >\n")

print("Thanks for your feedback!")
